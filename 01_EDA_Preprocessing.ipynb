# %% [markdown]
# <a href="https://colab.research.google.com/github/LaithAlzubaidi1/LAITH-HATEM-DS/blob/main/01_EDA_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("DS230 Project")
# Out:
# DS230 Project

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
